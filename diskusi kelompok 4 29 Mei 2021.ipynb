# %%
import psycopg2
import pandas as pd

def run(query):
    conn = psycopg2.connect(database = 'diskusi_kel4', user = "postgres", password = 'maftuh2003', host = "localhost", port = "5432")
    cur = conn.cursor()
#     cur.execute(query)
#     return cur.fetchall()
    return pd.read_sql(query, conn)

# %% [markdown]
# # No 1

# %%
query = "SELECT * FROM _offices ORDER BY country, state, city;"
run(query)
# Out:
#    officecode           city             phone              addressline1  \
# 0           6         Sydney   +61 2 9264 2451     5-11 Wentworth Avenue
# 1           4          Paris   +33 14 723 4404  43 Rue Jouffroy D'abbans
# 2           5          Tokyo   +81 33 224 5000               4-1 Kioicho
# 3           7         London  +44 20 7877 2041       25 Old Broad Street
# 4           1  San Francisco   +1 650 219 4782         100 Market Street
# 5           2         Boston   +1 215 837 0825          1550 Court Place
# 6           3            NYC   +1 212 555 3000      523 East 53rd Street
#
#   addressline2       state    country postalcode territory
# 0     Floor #2              Australia   NSW 2010      APAC
# 1                              France      75017      EMEA
# 2               Chiyoda-Ku      Japan   102-8578     Japan
# 3      Level 7                     UK   EC2N 1HN      EMEA
# 4    Suite 300          CA        USA      94080        NA
# 5    Suite 102          MA        USA      02107        NA
# 6      apt. 5A          NY        USA      10022        NA

# %% [markdown]
# # NO 2

# %%
query = "SELECT COUNT(employeenumber) FROM _employees"
run(query)
# Out:
#    count
# 0     23

# %% [markdown]
# # NO 3

# %%
run(
'''
SELECT SUM (amount) FROM _payments
'''
)
# Out:
#           sum
# 0  8853839.23

# %% [markdown]
# # No 4

# %%
query = '''
    SELECT * FROM _products
    WHERE productline LIKE '%Cars%';
'''
run(query)
# Out:
#     productcode                            productname   productline  \
# 0      S10_1678  1969 Harley Davidson Ultimate Chopper   Motorcycles
# 1      S10_1949               1952 Alpine Renault 1300  Classic Cars
# 2      S10_2016                  1996 Moto Guzzi 1100i   Motorcycles
# 3      S10_4698   2003 Harley-Davidson Eagle Drag Bike   Motorcycles
# 4      S10_4757                    1972 Alfa Romeo GTA  Classic Cars
# ..          ...                                    ...           ...
# 105   S700_3167                     F/A 18 Hornet 1/72        Planes
# 106   S700_3505                            The Titanic         Ships
# 107   S700_3962                         The Queen Mary         Ships
# 108   S700_4002              American Airlines: MD-11S        Planes
# 109    S72_3212                             Pont Yacht         Ships
#
#     productscale              productvendor  \
# 0           1:10            Min Lin Diecast
# 1           1:10    Classic Metal Creations
# 2           1:10   Highway 66 Mini Classics
# 3           1:10          Red Start Diecast
# 4           1:10    Motor City Art Classics
# ..           ...                        ...
# 105         1:72    Motor City Art Classics
# 106        1:700   Carousel DieCast Legends
# 107        1:700  Welly Diecast Productions
# 108        1:700        Second Gear Diecast
# 109         1:72       Unimax Art Galleries
#
#                                     productdescription  quantityinstock  \
# 0    This replica features working kickstand, front...             7933
# 1    Turnable front wheels; steering function; deta...             7305
# 2    Official Moto Guzzi logos and insignias, saddl...             6625
# 3    Model features, official Harley Davidson logos...             5582
# 4    Features include: Turnable front wheels; steer...             3252
# ..                                                 ...              ...
# 105  10" Wingspan with retractable landing gears.Co...              551
# 106  Completed model measures 19 1/2 inches long, 9...             1956
# 107  Exact replica. Wood and Metal. Many extras inc...             5088
# 108  Polished finish. Exact replia with official lo...             8820
# 109  Measures 38 inches Long x 33 3/4 inches High. ...              414
#
#      buyprice    msrp
# 0       48.81   95.70
# 1       98.58  214.30
# 2       68.99  118.94
# 3       91.02  193.66
# 4       85.68  136.00
# ..        ...     ...
# 105     54.40   80.00
# 106     51.09  100.17
# 107     53.63   99.31
# 108     36.27   74.03
# 109     33.30   54.60
#
# [110 rows x 9 columns]
